# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from IPython.display import Image

rc = {
    'axes.grid': False,
    'axes.edgecolor': 'lightgrey',
    'axes.spines.top': False,
    'axes.spines.right': False,
    'xtick.color': 'grey',
    'xtick.labelsize': 'small',
    'xtick.bottom': True,
    'xtick.major.size': 2.5,
    'ytick.color': 'grey',
    'ytick.major.size': 2.5,
    'ytick.left': True,
}

sns.set(style='whitegrid', rc=rc)

# %% [markdown]
# ### Programming exercises

# %%
Image('imgs/exercise.1.2.png')

# %%
true_f = lambda x: -2.314*x + 103.758

x = np.linspace(0, 3, 100)[:, np.newaxis]
y = true_f(x)

rng = np.random.RandomState(42)
noise = np.random.standard_normal(size=y.shape[0]) / 2.5

X = np.column_stack((np.ones_like(x), x))
t = y + noise[:, np.newaxis]

plt.figure(figsize=(12,8))
plt.plot(x, y, '-', label='True f(x)')
plt.plot(x, t, 'o', label='t')
plt.title('Simulated x_n, t_n pairs')
plt.xlabel('x')
plt.ylabel('t')
plt.legend()
plt.show()

# %%
class SimpleLinearRegression():
    
    def fit(self, X, y=None):
        self._w = np.linalg.inv(X.T @ X) @ (X.T @ y)
        return self
        
    def predict(self, X):
        return self._w.T @ X

# %%
lin_reg = SimpleLinearRegression()
lin_reg.fit(X, y)

print('True f: -2.314*x + 103.758')
print(f'Estimated w: {np.ravel(lin_reg._w)}')
# Out:
# True f: -2.314*x + 103.758
# Estimated w: [103.758  -2.314]
