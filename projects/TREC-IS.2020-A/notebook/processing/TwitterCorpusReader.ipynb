# %%
import sys
sys.path.append('../../src/')

from processing.corpus_readers import TRECISTweetCorpusReader

# %%
train_data_path = '../../data/prepared/train/'
corpus_reader = TRECISTweetCorpusReader(root=train_data_path)

# %%
corpus_reader.fileids()
# Out:
# ['Advice/bombing.bostonBombings2013.jsonl',
#  'Advice/bombing.westTexasExplosion2013.jsonl',
#  'Advice/earthquake.chileEarthquake2014.jsonl',
#  'Advice/earthquake.costaRicaEarthquake2012.jsonl',
#  'Advice/earthquake.earthquakeBohol2013.jsonl',
#  'Advice/earthquake.earthquakeCalifornia2014.jsonl',
#  'Advice/earthquake.guatemalaEarthquake2012.jsonl',
#  'Advice/earthquake.italyEarthquakes2012.jsonl',
#  'Advice/earthquake.nepalEarthquake2015.jsonl',
#  'Advice/flood.albertaFloods2013.jsonl',
#  'Advice/flood.floodChoco2019.jsonl',
#  'Advice/flood.floodColorado2013.jsonl',
#  'Advice/flood.philipinnesFloods2012.jsonl',
#  'Advice/flood.queenslandFloods2013.jsonl',
#  'Advice/flood.southAfricaFloods2019.jsonl',
#  'Advice/shooting.coloradoStemShooting2019.jsonl',
#  'Advice/shooting.flSchoolShooting2018.jsonl',
#  'Advice/shooting.sandiegoSynagogueShooting2019.jsonl',
#  'Advice/shooting.shootingDallas2017.jsonl',
#  'Advice/typhoon.cycloneKenneth2019.jsonl',
# ...

# %%
corpus_reader.categories()
# Out:
# ['Advice',
#  'CleanUp',
#  'ContextualInformation',
#  'Discussion',
#  'Donations',
#  'EmergingThreats',
#  'Factoid',
#  'FirstPartyObservation',
#  'GoodsServices',
#  'Hashtags',
#  'InformationWanted',
#  'Irrelevant',
#  'Location',
#  'MovePeople',
#  'MultimediaShare',
#  'NewSubEvent',
#  'News',
#  'Official',
#  'OriginalEvent',
#  'Priority',
#  'SearchAndRescue',
#  'Sentiment',
#  'ServiceAvailable',
#  'ThirdPartyObservation',
#  'Volunteer',
#  'Weather']

# %%
# corpus_reader.docs(corpus_reader.resolve(categories='Advice'))

# %%
corpus_reader.raw('Advice/bombing.bostonBombings2013.jsonl')
# Out:
# '{"created_at":1366056891000,"id":323892195365113857,"id_str":"323892195365113857","full_text":"Those poor people were raising money for their chosen charities. How could the human race do that to them! #prayforboston","truncated":false,"display_text_range":[0,121],"entities":{"hashtags":[{"text":"prayforboston","indices":[107,121]}],"symbols":[],"user_mentions":[],"urls":[]},"source":"<a href=\\"http:\\/\\/twitter.com\\/download\\/android\\" rel=\\"nofollow\\">Twitter for Android<\\/a>","in_reply_to_status_id":null,"in_reply_to_status_id_str":"None","in_reply_to_user_id":null,"in_reply_to_user_id_str":"None","in_reply_to_screen_name":null,"user":{"id":43869308,"id_str":"43869308","name":"Grant Hawkins","screen_name":"G17Hawkins","location":"Newport, Wales","description":"","url":null,"entities":{"description":{"urls":[]}},"protected":false,"followers_count":353,"friends_count":417,"listed_count":3,"created_at":"Mon Jun 01 11:31:11 +0000 2009","favourites_count":4188,"utc_offset":nul
# ...

# %%
corpus_reader.strings(fileids=['Advice/bombing.bostonBombings2013.jsonl'])
# Out:
# ['Those poor people were raising money for their chosen charities. How could the human race do that to them! #prayforboston',
#  "RT @awmannes: This pic sure doesn't look good - “@thedailybeast: aftermath of the Boston Marathon bombing (via @brm90) http://t.co/jKO2o ...",
#  "RT @RobGronkowski: Wow can't believe what just happened at the Boston Marathon. Praying for everyone down there.",
#  'O.O Oh no! :( RT @alicegoldfuss: Explosions at the Boston Marathon. Warning: blood. https://t.co/p9Yn9mknIT (via @theoriginalwak)',
#  "RT @cnnbrk: New York City has tightened security in wake of explosions at #Boston Marathon. We don't know extent of casualties. http://t ...",
#  'RT @mjbrender: All those concerned for loved ones in the #BostonMarathon - you can see where they last checked in here: http://t.co/gQT2 ...',
#  'RT @KCRG: ABC News is reporting that air quality experts have been brought into Boston to ensure explosions were not a chemical attack.',
# ...

# %%
corpus_reader.tokenized(fileids=['Advice/bombing.bostonBombings2013.jsonl'])
# Out:
# [['Those',
#   'poor',
#   'people',
#   'were',
#   'raising',
#   'money',
#   'for',
#   'their',
#   'chosen',
#   'charities',
#   '.',
#   'How',
#   'could',
#   'the',
#   'human',
#   'race',
#   'do',
#   'that',
#   'to',
#   'them',
#   '!',
#   '#prayforboston'],
#  ['RT',
#   '@awmannes',
#   ':',
#   'This',
#   'pic',
#   'sure',
#   "doesn't",
#   'look',
#   'good',
#   '-',
#   '“',
#   '@thedailybeast',
#   ':',
#   'aftermath',
#   'of',
#   'the',
#   'Boston',
#   'Marathon',
#   'bombing',
#   '(',
#   'via',
#   '@brm90',
#   ')',
#   'http://t.co/jKO2o',
#   '...'],
#  ['RT',
#   '@RobGronkowski',
#   ':',
#   'Wow',
#   "can't",
#   'believe',
#   'what',
#   'just',
#   'happened',
#   'at',
#   'the',
#   'Boston',
#   'Marathon',
#   '.',
#   'Praying',
#   'for',
#   'everyone',
#   'down',
#   'there',
#   '.'],
#  ['O',
#   '.',
#   'O',
#   'Oh',
#   'no',
#   '!',
#   ':(',
#   'RT',
#   '@alicegoldfuss',
#   ':',
#   'Explosions',
#   'at',
# ...
