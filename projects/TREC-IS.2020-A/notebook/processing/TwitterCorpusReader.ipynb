# %%
from nltk.corpus.reader.api import CategorizedCorpusReader
from nltk.corpus.reader.twitter import TwitterCorpusReader

import os

# %%
CAT_PATTERN = r'(\w+)/.*'
DOC_PATTERN = r'.*.jsonl'
ATTRIBS = ['full_text']

train_data_path = '../../data/prepared/train/'

class TRECISTweetCorpusReader(CategorizedCorpusReader, TwitterCorpusReader):
    """
    A corpus reader for raw line-delimited JSON documents (Tweets)
    to enable preprocessing.
    
    Examples drawn and adapted from Applied Text Analysis with Python
    by Benjamin Bengfort, Rebecca Bilbro, and Tony Ojeda (O'Reilly).
    978-1-491-96304-3.
    """

    
    def __init__(self, root, fileids=DOC_PATTERN, encoding='utf8', 
                 attribs=ATTRIBS, single_cat='Advice', **kwargs):
        """
        Initialize the corpus reader.  Categorization arguments
        (``cat_pattern``, ``cat_map``, and ``cat_file``) are passed to
        the ``CategorizedCorpusReader`` constructor.  The remaining
        arguments are passed to the ``TwitterCorpusReader`` constructor.
        
        ``single_cat`` is the singled-out category from which we draw
        Tweets since they are duplicated across categories with only
        ``target`` attribute values as different.
        """
        
        # Add the default category pattern if not passed into the class.
        if not any(key.startswith('cat_') for key in kwargs.keys()):
            kwargs['cat_pattern'] = CAT_PATTERN
        
        # Initialize the NLTK corpus reader object
        CategorizedCorpusReader.__init__(self, kwargs)
        TwitterCorpusReader.__init__(self, root, fileids, encoding) 
        
        # Save the Tweet attributes that we specifically want to extract.
        self.attribs = attribs
        
        """
        Store fileids of a singled-out category since Tweets are duplicated 
        across categories (with only ``target`` attribute values as different)
        """
        self.single_cat = self.fileids(categories='Advice')
        
    
    def strings(self, fileids=None):
        """
        Returns only the text content of Tweets in the file(s)
        Overrides TwitterCorpusReader.strings method to return 
        'full_text' attribute of a Tweet instead of ``text``

        :return: the given file(s) as a list of Tweets.
        :rtype: list(str)
        """
        if fileids is None:
            fileids = self.single_cat
            
        fulltweets = self.docs(fileids)
        tweets = []
        
        for jsono in fulltweets:
            try:
                text = jsono['full_text']
                if isinstance(text, bytes):
                    text = text.decode(self.encoding)
                tweets.append(text)
            except KeyError:
                pass
            
        return tweets
    
    
    def resolve(self, fileids=None, categories=None):
        """
        Returns a list of fileids or categories depending on what is passed
        to each internal corpus reader function. Implemented similarly to
        the NLTK ``CategorizedPlaintextCorpusReader``.
        """
        if fileids is not None and categories is not None:
            raise ValueError('Specify fileids or categories, not both')
            
        if categories is not None:
            return self.fileids(categories)
        
        return fileids
    
    
    def sizes(self, fileids=None, categories=None):
        """
        Returns a list of tuples, the fileid and size on disk of the file.
        This function is used to detect oddly large files in the corpus.
        """
        
        # Resolve fileids and the categories
        fileids = self.resolve(fileids, categories)
        
        # Create a generator, getting every path and compute filesize
        for path in self.abspaths(fileids):
            yield os.path.getsize(path)
        

corpus_reader = TRECISTweetCorpusReader(root=train_data_path)

# %%
corpus_reader.fileids()
# Out:
# ['Advice/bombing.bostonBombings2013.jsonl',
#  'Advice/bombing.westTexasExplosion2013.jsonl',
#  'Advice/earthquake.chileEarthquake2014.jsonl',
#  'Advice/earthquake.costaRicaEarthquake2012.jsonl',
#  'Advice/earthquake.earthquakeBohol2013.jsonl',
#  'Advice/earthquake.earthquakeCalifornia2014.jsonl',
#  'Advice/earthquake.guatemalaEarthquake2012.jsonl',
#  'Advice/earthquake.italyEarthquakes2012.jsonl',
#  'Advice/earthquake.nepalEarthquake2015.jsonl',
#  'Advice/flood.albertaFloods2013.jsonl',
#  'Advice/flood.floodChoco2019.jsonl',
#  'Advice/flood.floodColorado2013.jsonl',
#  'Advice/flood.philipinnesFloods2012.jsonl',
#  'Advice/flood.queenslandFloods2013.jsonl',
#  'Advice/flood.southAfricaFloods2019.jsonl',
#  'Advice/shooting.coloradoStemShooting2019.jsonl',
#  'Advice/shooting.flSchoolShooting2018.jsonl',
#  'Advice/shooting.sandiegoSynagogueShooting2019.jsonl',
#  'Advice/shooting.shootingDallas2017.jsonl',
#  'Advice/typhoon.cycloneKenneth2019.jsonl',
#  'Advice/typhoon.joplinTornado2011.jsonl',
#  'Advice/typhoon.typhoonHagupit2014.jsonl',
#  'Advice/typhoon.typhoonPablo2012.jsonl',
#  'Advice/typhoon.typhoonYolanda2013.jsonl',
#  'Advice/wildfire.australiaBushfire2013.jsonl',
#  'Advice/wildfire.fireColorado2012.jsonl',
#  'Advice/wildfire.fireYMM2016.jsonl',
#  'CleanUp/bombing.bostonBombings2013.jsonl',
#  'CleanUp/bombing.westTexasExplosion2013.jsonl',
#  'CleanUp/earthquake.chileEarthquake2014.jsonl',
#  'CleanUp/earthquake.costaRicaEarthquake2012.jsonl',
#  'CleanUp/earthquake.earthquakeBohol2013.jsonl',
#  'CleanUp/earthquake.earthquakeCalifornia2014.jsonl',
#  'CleanUp/earthquake.guatemalaEarthquake2012.jsonl',
#  'CleanUp/earthquake.italyEarthquakes2012.jsonl',
#  'CleanUp/earthquake.nepalEarthquake2015.jsonl',
#  'CleanUp/flood.albertaFloods2013.jsonl',
#  'CleanUp/flood.floodChoco2019.jsonl',
#  'CleanUp/flood.floodColorado2013.jsonl',
#  'CleanUp/flood.philipinnesFloods2012.jsonl',
#  'CleanUp/flood.queenslandFloods2013.jsonl',
#  'CleanUp/flood.southAfricaFloods2019.jsonl',
#  'CleanUp/shooting.coloradoStemShooting2019.jsonl',
#  'CleanUp/shooting.flSchoolShooting2018.jsonl',
#  'CleanUp/shooting.sandiegoSynagogueShooting2019.jsonl',
#  'CleanUp/shooting.shootingDallas2017.jsonl',
#  'CleanUp/typhoon.cycloneKenneth2019.jsonl',
#  'CleanUp/typhoon.joplinTornado2011.jsonl',
#  'CleanUp/typhoon.typhoonHagupit2014.jsonl',
#  'CleanUp/typhoon.typhoonPablo2012.jsonl',
#  'CleanUp/typhoon.typhoonYolanda2013.jsonl',
#  'CleanUp/wildfire.australiaBushfire2013.jsonl',
#  'CleanUp/wildfire.fireColorado2012.jsonl',
#  'CleanUp/wildfire.fireYMM2016.jsonl',
#  'ContextualInformation/bombing.bostonBombings2013.jsonl',
#  'ContextualInformation/bombing.westTexasExplosion2013.jsonl',
#  'ContextualInformation/earthquake.chileEarthquake2014.jsonl',
#  'ContextualInformation/earthquake.costaRicaEarthquake2012.jsonl',
#  'ContextualInformation/earthquake.earthquakeBohol2013.jsonl',
#  'ContextualInformation/earthquake.earthquakeCalifornia2014.jsonl',
#  'ContextualInformation/earthquake.guatemalaEarthquake2012.jsonl',
#  'ContextualInformation/earthquake.italyEarthquakes2012.jsonl',
#  'ContextualInformation/earthquake.nepalEarthquake2015.jsonl',
#  'ContextualInformation/flood.albertaFloods2013.jsonl',
#  'ContextualInformation/flood.floodChoco2019.jsonl',
#  'ContextualInformation/flood.floodColorado2013.jsonl',
#  'ContextualInformation/flood.philipinnesFloods2012.jsonl',
#  'ContextualInformation/flood.queenslandFloods2013.jsonl',
#  'ContextualInformation/flood.southAfricaFloods2019.jsonl',
#  'ContextualInformation/shooting.coloradoStemShooting2019.jsonl',
#  'ContextualInformation/shooting.flSchoolShooting2018.jsonl',
#  'ContextualInformation/shooting.sandiegoSynagogueShooting2019.jsonl',
#  'ContextualInformation/shooting.shootingDallas2017.jsonl',
#  'ContextualInformation/typhoon.cycloneKenneth2019.jsonl',
#  'ContextualInformation/typhoon.joplinTornado2011.jsonl',
#  'ContextualInformation/typhoon.typhoonHagupit2014.jsonl',
#  'ContextualInformation/typhoon.typhoonPablo2012.jsonl',
#  'ContextualInformation/typhoon.typhoonYolanda2013.jsonl',
#  'ContextualInformation/wildfire.australiaBushfire2013.jsonl',
#  'ContextualInformation/wildfire.fireColorado2012.jsonl',
#  'ContextualInformation/wildfire.fireYMM2016.jsonl',
#  'Discussion/bombing.bostonBombings2013.jsonl',
#  'Discussion/bombing.westTexasExplosion2013.jsonl',
#  'Discussion/earthquake.chileEarthquake2014.jsonl',
#  'Discussion/earthquake.costaRicaEarthquake2012.jsonl',
#  'Discussion/earthquake.earthquakeBohol2013.jsonl',
#  'Discussion/earthquake.earthquakeCalifornia2014.jsonl',
#  'Discussion/earthquake.guatemalaEarthquake2012.jsonl',
#  'Discussion/earthquake.italyEarthquakes2012.jsonl',
#  'Discussion/earthquake.nepalEarthquake2015.jsonl',
#  'Discussion/flood.albertaFloods2013.jsonl',
#  'Discussion/flood.floodChoco2019.jsonl',
#  'Discussion/flood.floodColorado2013.jsonl',
#  'Discussion/flood.philipinnesFloods2012.jsonl',
#  'Discussion/flood.queenslandFloods2013.jsonl',
#  'Discussion/flood.southAfricaFloods2019.jsonl',
#  'Discussion/shooting.coloradoStemShooting2019.jsonl',
#  'Discussion/shooting.flSchoolShooting2018.jsonl',
#  'Discussion/shooting.sandiegoSynagogueShooting2019.jsonl',
#  'Discussion/shooting.shootingDallas2017.jsonl',
#  'Discussion/typhoon.cycloneKenneth2019.jsonl',
#  'Discussion/typhoon.joplinTornado2011.jsonl',
#  'Discussion/typhoon.typhoonHagupit2014.jsonl',
#  'Discussion/typhoon.typhoonPablo2012.jsonl',
#  'Discussion/typhoon.typhoonYolanda2013.jsonl',
#  'Discussion/wildfire.australiaBushfire2013.jsonl',
#  'Discussion/wildfire.fireColorado2012.jsonl',
#  'Discussion/wildfire.fireYMM2016.jsonl',
#  'Donations/bombing.bostonBombings2013.jsonl',
#  'Donations/bombing.westTexasExplosion2013.jsonl',
#  'Donations/earthquake.chileEarthquake2014.jsonl',
#  'Donations/earthquake.costaRicaEarthquake2012.jsonl',
#  'Donations/earthquake.earthquakeBohol2013.jsonl',
#  'Donations/earthquake.earthquakeCalifornia2014.jsonl',
#  'Donations/earthquake.guatemalaEarthquake2012.jsonl',
#  'Donations/earthquake.italyEarthquakes2012.jsonl',
#  'Donations/earthquake.nepalEarthquake2015.jsonl',
#  'Donations/flood.albertaFloods2013.jsonl',
#  'Donations/flood.floodChoco2019.jsonl',
#  'Donations/flood.floodColorado2013.jsonl',
#  'Donations/flood.philipinnesFloods2012.jsonl',
#  'Donations/flood.queenslandFloods2013.jsonl',
#  'Donations/flood.southAfricaFloods2019.jsonl',
#  'Donations/shooting.coloradoStemShooting2019.jsonl',
#  'Donations/shooting.flSchoolShooting2018.jsonl',
#  'Donations/shooting.sandiegoSynagogueShooting2019.jsonl',
#  'Donations/shooting.shootingDallas2017.jsonl',
#  'Donations/typhoon.cycloneKenneth2019.jsonl',
#  'Donations/typhoon.joplinTornado2011.jsonl',
#  'Donations/typhoon.typhoonHagupit2014.jsonl',
#  'Donations/typhoon.typhoonPablo2012.jsonl',
#  'Donations/typhoon.typhoonYolanda2013.jsonl',
#  'Donations/wildfire.australiaBushfire2013.jsonl',
#  'Donations/wildfire.fireColorado2012.jsonl',
#  'Donations/wildfire.fireYMM2016.jsonl',
#  'EmergingThreats/bombing.bostonBombings2013.jsonl',
#  'EmergingThreats/bombing.westTexasExplosion2013.jsonl',
#  'EmergingThreats/earthquake.chileEarthquake2014.jsonl',
#  'EmergingThreats/earthquake.costaRicaEarthquake2012.jsonl',
#  'EmergingThreats/earthquake.earthquakeBohol2013.jsonl',
#  'EmergingThreats/earthquake.earthquakeCalifornia2014.jsonl',
#  'EmergingThreats/earthquake.guatemalaEarthquake2012.jsonl',
#  'EmergingThreats/earthquake.italyEarthquakes2012.jsonl',
#  'EmergingThreats/earthquake.nepalEarthquake2015.jsonl',
#  'EmergingThreats/flood.albertaFloods2013.jsonl',
#  'EmergingThreats/flood.floodChoco2019.jsonl',
#  'EmergingThreats/flood.floodColorado2013.jsonl',
#  'EmergingThreats/flood.philipinnesFloods2012.jsonl',
#  'EmergingThreats/flood.queenslandFloods2013.jsonl',
#  'EmergingThreats/flood.southAfricaFloods2019.jsonl',
#  'EmergingThreats/shooting.coloradoStemShooting2019.jsonl',
#  'EmergingThreats/shooting.flSchoolShooting2018.jsonl',
#  'EmergingThreats/shooting.sandiegoSynagogueShooting2019.jsonl',
#  'EmergingThreats/shooting.shootingDallas2017.jsonl',
#  'EmergingThreats/typhoon.cycloneKenneth2019.jsonl',
#  'EmergingThreats/typhoon.joplinTornado2011.jsonl',
#  'EmergingThreats/typhoon.typhoonHagupit2014.jsonl',
#  'EmergingThreats/typhoon.typhoonPablo2012.jsonl',
#  'EmergingThreats/typhoon.typhoonYolanda2013.jsonl',
#  'EmergingThreats/wildfire.australiaBushfire2013.jsonl',
#  'EmergingThreats/wildfire.fireColorado2012.jsonl',
#  'EmergingThreats/wildfire.fireYMM2016.jsonl',
#  'Factoid/bombing.bostonBombings2013.jsonl',
#  'Factoid/bombing.westTexasExplosion2013.jsonl',
#  'Factoid/earthquake.chileEarthquake2014.jsonl',
#  'Factoid/earthquake.costaRicaEarthquake2012.jsonl',
#  'Factoid/earthquake.earthquakeBohol2013.jsonl',
#  'Factoid/earthquake.earthquakeCalifornia2014.jsonl',
#  'Factoid/earthquake.guatemalaEarthquake2012.jsonl',
#  'Factoid/earthquake.italyEarthquakes2012.jsonl',
#  'Factoid/earthquake.nepalEarthquake2015.jsonl',
#  'Factoid/flood.albertaFloods2013.jsonl',
#  'Factoid/flood.floodChoco2019.jsonl',
#  'Factoid/flood.floodColorado2013.jsonl',
#  'Factoid/flood.philipinnesFloods2012.jsonl',
#  'Factoid/flood.queenslandFloods2013.jsonl',
#  'Factoid/flood.southAfricaFloods2019.jsonl',
#  'Factoid/shooting.coloradoStemShooting2019.jsonl',
#  'Factoid/shooting.flSchoolShooting2018.jsonl',
#  'Factoid/shooting.sandiegoSynagogueShooting2019.jsonl',
#  'Factoid/shooting.shootingDallas2017.jsonl',
#  'Factoid/typhoon.cycloneKenneth2019.jsonl',
#  'Factoid/typhoon.joplinTornado2011.jsonl',
#  'Factoid/typhoon.typhoonHagupit2014.jsonl',
#  'Factoid/typhoon.typhoonPablo2012.jsonl',
#  'Factoid/typhoon.typhoonYolanda2013.jsonl',
#  'Factoid/wildfire.australiaBushfire2013.jsonl',
#  'Factoid/wildfire.fireColorado2012.jsonl',
#  'Factoid/wildfire.fireYMM2016.jsonl',
#  'FirstPartyObservation/bombing.bostonBombings2013.jsonl',
#  'FirstPartyObservation/bombing.westTexasExplosion2013.jsonl',
#  'FirstPartyObservation/earthquake.chileEarthquake2014.jsonl',
#  'FirstPartyObservation/earthquake.costaRicaEarthquake2012.jsonl',
#  'FirstPartyObservation/earthquake.earthquakeBohol2013.jsonl',
#  'FirstPartyObservation/earthquake.earthquakeCalifornia2014.jsonl',
#  'FirstPartyObservation/earthquake.guatemalaEarthquake2012.jsonl',
#  'FirstPartyObservation/earthquake.italyEarthquakes2012.jsonl',
#  'FirstPartyObservation/earthquake.nepalEarthquake2015.jsonl',
#  'FirstPartyObservation/flood.albertaFloods2013.jsonl',
#  'FirstPartyObservation/flood.floodChoco2019.jsonl',
#  'FirstPartyObservation/flood.floodColorado2013.jsonl',
#  'FirstPartyObservation/flood.philipinnesFloods2012.jsonl',
#  'FirstPartyObservation/flood.queenslandFloods2013.jsonl',
#  'FirstPartyObservation/flood.southAfricaFloods2019.jsonl',
#  'FirstPartyObservation/shooting.coloradoStemShooting2019.jsonl',
#  'FirstPartyObservation/shooting.flSchoolShooting2018.jsonl',
#  'FirstPartyObservation/shooting.sandiegoSynagogueShooting2019.jsonl',
#  'FirstPartyObservation/shooting.shootingDallas2017.jsonl',
#  'FirstPartyObservation/typhoon.cycloneKenneth2019.jsonl',
#  'FirstPartyObservation/typhoon.joplinTornado2011.jsonl',
#  'FirstPartyObservation/typhoon.typhoonHagupit2014.jsonl',
#  'FirstPartyObservation/typhoon.typhoonPablo2012.jsonl',
#  'FirstPartyObservation/typhoon.typhoonYolanda2013.jsonl',
#  'FirstPartyObservation/wildfire.australiaBushfire2013.jsonl',
#  'FirstPartyObservation/wildfire.fireColorado2012.jsonl',
#  'FirstPartyObservation/wildfire.fireYMM2016.jsonl',
#  'GoodsServices/bombing.bostonBombings2013.jsonl',
#  'GoodsServices/bombing.westTexasExplosion2013.jsonl',
#  'GoodsServices/earthquake.chileEarthquake2014.jsonl',
#  'GoodsServices/earthquake.costaRicaEarthquake2012.jsonl',
#  'GoodsServices/earthquake.earthquakeBohol2013.jsonl',
#  'GoodsServices/earthquake.earthquakeCalifornia2014.jsonl',
#  'GoodsServices/earthquake.guatemalaEarthquake2012.jsonl',
#  'GoodsServices/earthquake.italyEarthquakes2012.jsonl',
#  'GoodsServices/earthquake.nepalEarthquake2015.jsonl',
#  'GoodsServices/flood.albertaFloods2013.jsonl',
#  'GoodsServices/flood.floodChoco2019.jsonl',
#  'GoodsServices/flood.floodColorado2013.jsonl',
#  'GoodsServices/flood.philipinnesFloods2012.jsonl',
#  'GoodsServices/flood.queenslandFloods2013.jsonl',
#  'GoodsServices/flood.southAfricaFloods2019.jsonl',
#  'GoodsServices/shooting.coloradoStemShooting2019.jsonl',
#  'GoodsServices/shooting.flSchoolShooting2018.jsonl',
#  'GoodsServices/shooting.sandiegoSynagogueShooting2019.jsonl',
#  'GoodsServices/shooting.shootingDallas2017.jsonl',
#  'GoodsServices/typhoon.cycloneKenneth2019.jsonl',
#  'GoodsServices/typhoon.joplinTornado2011.jsonl',
#  'GoodsServices/typhoon.typhoonHagupit2014.jsonl',
#  'GoodsServices/typhoon.typhoonPablo2012.jsonl',
#  'GoodsServices/typhoon.typhoonYolanda2013.jsonl',
#  'GoodsServices/wildfire.australiaBushfire2013.jsonl',
#  'GoodsServices/wildfire.fireColorado2012.jsonl',
#  'GoodsServices/wildfire.fireYMM2016.jsonl',
#  'Hashtags/bombing.bostonBombings2013.jsonl',
#  'Hashtags/bombing.westTexasExplosion2013.jsonl',
#  'Hashtags/earthquake.chileEarthquake2014.jsonl',
#  'Hashtags/earthquake.costaRicaEarthquake2012.jsonl',
#  'Hashtags/earthquake.earthquakeBohol2013.jsonl',
#  'Hashtags/earthquake.earthquakeCalifornia2014.jsonl',
#  'Hashtags/earthquake.guatemalaEarthquake2012.jsonl',
#  'Hashtags/earthquake.italyEarthquakes2012.jsonl',
#  'Hashtags/earthquake.nepalEarthquake2015.jsonl',
#  'Hashtags/flood.albertaFloods2013.jsonl',
#  'Hashtags/flood.floodChoco2019.jsonl',
#  'Hashtags/flood.floodColorado2013.jsonl',
#  'Hashtags/flood.philipinnesFloods2012.jsonl',
#  'Hashtags/flood.queenslandFloods2013.jsonl',
#  'Hashtags/flood.southAfricaFloods2019.jsonl',
#  'Hashtags/shooting.coloradoStemShooting2019.jsonl',
#  'Hashtags/shooting.flSchoolShooting2018.jsonl',
#  'Hashtags/shooting.sandiegoSynagogueShooting2019.jsonl',
#  'Hashtags/shooting.shootingDallas2017.jsonl',
#  'Hashtags/typhoon.cycloneKenneth2019.jsonl',
#  'Hashtags/typhoon.joplinTornado2011.jsonl',
#  'Hashtags/typhoon.typhoonHagupit2014.jsonl',
#  'Hashtags/typhoon.typhoonPablo2012.jsonl',
#  'Hashtags/typhoon.typhoonYolanda2013.jsonl',
#  'Hashtags/wildfire.australiaBushfire2013.jsonl',
#  'Hashtags/wildfire.fireColorado2012.jsonl',
#  'Hashtags/wildfire.fireYMM2016.jsonl',
#  'InformationWanted/bombing.bostonBombings2013.jsonl',
#  'InformationWanted/bombing.westTexasExplosion2013.jsonl',
#  'InformationWanted/earthquake.chileEarthquake2014.jsonl',
#  'InformationWanted/earthquake.costaRicaEarthquake2012.jsonl',
#  'InformationWanted/earthquake.earthquakeBohol2013.jsonl',
#  'InformationWanted/earthquake.earthquakeCalifornia2014.jsonl',
#  'InformationWanted/earthquake.guatemalaEarthquake2012.jsonl',
#  'InformationWanted/earthquake.italyEarthquakes2012.jsonl',
#  'InformationWanted/earthquake.nepalEarthquake2015.jsonl',
#  'InformationWanted/flood.albertaFloods2013.jsonl',
#  'InformationWanted/flood.floodChoco2019.jsonl',
#  'InformationWanted/flood.floodColorado2013.jsonl',
#  'InformationWanted/flood.philipinnesFloods2012.jsonl',
#  'InformationWanted/flood.queenslandFloods2013.jsonl',
#  'InformationWanted/flood.southAfricaFloods2019.jsonl',
#  'InformationWanted/shooting.coloradoStemShooting2019.jsonl',
#  'InformationWanted/shooting.flSchoolShooting2018.jsonl',
#  'InformationWanted/shooting.sandiegoSynagogueShooting2019.jsonl',
#  'InformationWanted/shooting.shootingDallas2017.jsonl',
#  'InformationWanted/typhoon.cycloneKenneth2019.jsonl',
#  'InformationWanted/typhoon.joplinTornado2011.jsonl',
#  'InformationWanted/typhoon.typhoonHagupit2014.jsonl',
#  'InformationWanted/typhoon.typhoonPablo2012.jsonl',
#  'InformationWanted/typhoon.typhoonYolanda2013.jsonl',
#  'InformationWanted/wildfire.australiaBushfire2013.jsonl',
#  'InformationWanted/wildfire.fireColorado2012.jsonl',
#  'InformationWanted/wildfire.fireYMM2016.jsonl',
#  'Irrelevant/bombing.bostonBombings2013.jsonl',
#  'Irrelevant/bombing.westTexasExplosion2013.jsonl',
#  'Irrelevant/earthquake.chileEarthquake2014.jsonl',
#  'Irrelevant/earthquake.costaRicaEarthquake2012.jsonl',
#  'Irrelevant/earthquake.earthquakeBohol2013.jsonl',
#  'Irrelevant/earthquake.earthquakeCalifornia2014.jsonl',
#  'Irrelevant/earthquake.guatemalaEarthquake2012.jsonl',
#  'Irrelevant/earthquake.italyEarthquakes2012.jsonl',
#  'Irrelevant/earthquake.nepalEarthquake2015.jsonl',
#  'Irrelevant/flood.albertaFloods2013.jsonl',
#  'Irrelevant/flood.floodChoco2019.jsonl',
#  'Irrelevant/flood.floodColorado2013.jsonl',
#  'Irrelevant/flood.philipinnesFloods2012.jsonl',
#  'Irrelevant/flood.queenslandFloods2013.jsonl',
#  'Irrelevant/flood.southAfricaFloods2019.jsonl',
#  'Irrelevant/shooting.coloradoStemShooting2019.jsonl',
#  'Irrelevant/shooting.flSchoolShooting2018.jsonl',
#  'Irrelevant/shooting.sandiegoSynagogueShooting2019.jsonl',
#  'Irrelevant/shooting.shootingDallas2017.jsonl',
#  'Irrelevant/typhoon.cycloneKenneth2019.jsonl',
#  'Irrelevant/typhoon.joplinTornado2011.jsonl',
#  'Irrelevant/typhoon.typhoonHagupit2014.jsonl',
#  'Irrelevant/typhoon.typhoonPablo2012.jsonl',
#  'Irrelevant/typhoon.typhoonYolanda2013.jsonl',
#  'Irrelevant/wildfire.australiaBushfire2013.jsonl',
#  'Irrelevant/wildfire.fireColorado2012.jsonl',
#  'Irrelevant/wildfire.fireYMM2016.jsonl',
#  'Location/bombing.bostonBombings2013.jsonl',
#  'Location/bombing.westTexasExplosion2013.jsonl',
#  'Location/earthquake.chileEarthquake2014.jsonl',
#  'Location/earthquake.costaRicaEarthquake2012.jsonl',
#  'Location/earthquake.earthquakeBohol2013.jsonl',
#  'Location/earthquake.earthquakeCalifornia2014.jsonl',
#  'Location/earthquake.guatemalaEarthquake2012.jsonl',
#  'Location/earthquake.italyEarthquakes2012.jsonl',
#  'Location/earthquake.nepalEarthquake2015.jsonl',
#  'Location/flood.albertaFloods2013.jsonl',
#  'Location/flood.floodChoco2019.jsonl',
#  'Location/flood.floodColorado2013.jsonl',
#  'Location/flood.philipinnesFloods2012.jsonl',
#  'Location/flood.queenslandFloods2013.jsonl',
#  'Location/flood.southAfricaFloods2019.jsonl',
#  'Location/shooting.coloradoStemShooting2019.jsonl',
#  'Location/shooting.flSchoolShooting2018.jsonl',
#  'Location/shooting.sandiegoSynagogueShooting2019.jsonl',
#  'Location/shooting.shootingDallas2017.jsonl',
#  'Location/typhoon.cycloneKenneth2019.jsonl',
#  'Location/typhoon.joplinTornado2011.jsonl',
#  'Location/typhoon.typhoonHagupit2014.jsonl',
#  'Location/typhoon.typhoonPablo2012.jsonl',
#  'Location/typhoon.typhoonYolanda2013.jsonl',
#  'Location/wildfire.australiaBushfire2013.jsonl',
#  'Location/wildfire.fireColorado2012.jsonl',
#  'Location/wildfire.fireYMM2016.jsonl',
#  'MovePeople/bombing.bostonBombings2013.jsonl',
#  'MovePeople/bombing.westTexasExplosion2013.jsonl',
#  'MovePeople/earthquake.chileEarthquake2014.jsonl',
#  'MovePeople/earthquake.costaRicaEarthquake2012.jsonl',
#  'MovePeople/earthquake.earthquakeBohol2013.jsonl',
#  'MovePeople/earthquake.earthquakeCalifornia2014.jsonl',
#  'MovePeople/earthquake.guatemalaEarthquake2012.jsonl',
#  'MovePeople/earthquake.italyEarthquakes2012.jsonl',
#  'MovePeople/earthquake.nepalEarthquake2015.jsonl',
#  'MovePeople/flood.albertaFloods2013.jsonl',
#  'MovePeople/flood.floodChoco2019.jsonl',
#  'MovePeople/flood.floodColorado2013.jsonl',
#  'MovePeople/flood.philipinnesFloods2012.jsonl',
#  'MovePeople/flood.queenslandFloods2013.jsonl',
#  'MovePeople/flood.southAfricaFloods2019.jsonl',
#  'MovePeople/shooting.coloradoStemShooting2019.jsonl',
#  'MovePeople/shooting.flSchoolShooting2018.jsonl',
#  'MovePeople/shooting.sandiegoSynagogueShooting2019.jsonl',
#  'MovePeople/shooting.shootingDallas2017.jsonl',
#  'MovePeople/typhoon.cycloneKenneth2019.jsonl',
#  'MovePeople/typhoon.joplinTornado2011.jsonl',
#  'MovePeople/typhoon.typhoonHagupit2014.jsonl',
#  'MovePeople/typhoon.typhoonPablo2012.jsonl',
#  'MovePeople/typhoon.typhoonYolanda2013.jsonl',
#  'MovePeople/wildfire.australiaBushfire2013.jsonl',
#  'MovePeople/wildfire.fireColorado2012.jsonl',
#  'MovePeople/wildfire.fireYMM2016.jsonl',
#  'MultimediaShare/bombing.bostonBombings2013.jsonl',
#  'MultimediaShare/bombing.westTexasExplosion2013.jsonl',
#  'MultimediaShare/earthquake.chileEarthquake2014.jsonl',
#  'MultimediaShare/earthquake.costaRicaEarthquake2012.jsonl',
#  'MultimediaShare/earthquake.earthquakeBohol2013.jsonl',
#  'MultimediaShare/earthquake.earthquakeCalifornia2014.jsonl',
#  'MultimediaShare/earthquake.guatemalaEarthquake2012.jsonl',
#  'MultimediaShare/earthquake.italyEarthquakes2012.jsonl',
#  'MultimediaShare/earthquake.nepalEarthquake2015.jsonl',
#  'MultimediaShare/flood.albertaFloods2013.jsonl',
#  'MultimediaShare/flood.floodChoco2019.jsonl',
#  'MultimediaShare/flood.floodColorado2013.jsonl',
#  'MultimediaShare/flood.philipinnesFloods2012.jsonl',
#  'MultimediaShare/flood.queenslandFloods2013.jsonl',
#  'MultimediaShare/flood.southAfricaFloods2019.jsonl',
#  'MultimediaShare/shooting.coloradoStemShooting2019.jsonl',
#  'MultimediaShare/shooting.flSchoolShooting2018.jsonl',
#  'MultimediaShare/shooting.sandiegoSynagogueShooting2019.jsonl',
#  'MultimediaShare/shooting.shootingDallas2017.jsonl',
#  'MultimediaShare/typhoon.cycloneKenneth2019.jsonl',
#  'MultimediaShare/typhoon.joplinTornado2011.jsonl',
#  'MultimediaShare/typhoon.typhoonHagupit2014.jsonl',
#  'MultimediaShare/typhoon.typhoonPablo2012.jsonl',
#  'MultimediaShare/typhoon.typhoonYolanda2013.jsonl',
#  'MultimediaShare/wildfire.australiaBushfire2013.jsonl',
#  'MultimediaShare/wildfire.fireColorado2012.jsonl',
#  'MultimediaShare/wildfire.fireYMM2016.jsonl',
#  'NewSubEvent/bombing.bostonBombings2013.jsonl',
#  'NewSubEvent/bombing.westTexasExplosion2013.jsonl',
#  'NewSubEvent/earthquake.chileEarthquake2014.jsonl',
#  'NewSubEvent/earthquake.costaRicaEarthquake2012.jsonl',
#  'NewSubEvent/earthquake.earthquakeBohol2013.jsonl',
#  'NewSubEvent/earthquake.earthquakeCalifornia2014.jsonl',
#  'NewSubEvent/earthquake.guatemalaEarthquake2012.jsonl',
#  'NewSubEvent/earthquake.italyEarthquakes2012.jsonl',
#  'NewSubEvent/earthquake.nepalEarthquake2015.jsonl',
#  'NewSubEvent/flood.albertaFloods2013.jsonl',
#  'NewSubEvent/flood.floodChoco2019.jsonl',
#  'NewSubEvent/flood.floodColorado2013.jsonl',
#  'NewSubEvent/flood.philipinnesFloods2012.jsonl',
#  'NewSubEvent/flood.queenslandFloods2013.jsonl',
#  'NewSubEvent/flood.southAfricaFloods2019.jsonl',
#  'NewSubEvent/shooting.coloradoStemShooting2019.jsonl',
#  'NewSubEvent/shooting.flSchoolShooting2018.jsonl',
#  'NewSubEvent/shooting.sandiegoSynagogueShooting2019.jsonl',
#  'NewSubEvent/shooting.shootingDallas2017.jsonl',
#  'NewSubEvent/typhoon.cycloneKenneth2019.jsonl',
#  'NewSubEvent/typhoon.joplinTornado2011.jsonl',
#  'NewSubEvent/typhoon.typhoonHagupit2014.jsonl',
#  'NewSubEvent/typhoon.typhoonPablo2012.jsonl',
#  'NewSubEvent/typhoon.typhoonYolanda2013.jsonl',
#  'NewSubEvent/wildfire.australiaBushfire2013.jsonl',
#  'NewSubEvent/wildfire.fireColorado2012.jsonl',
#  'NewSubEvent/wildfire.fireYMM2016.jsonl',
#  'News/bombing.bostonBombings2013.jsonl',
#  'News/bombing.westTexasExplosion2013.jsonl',
#  'News/earthquake.chileEarthquake2014.jsonl',
#  'News/earthquake.costaRicaEarthquake2012.jsonl',
#  'News/earthquake.earthquakeBohol2013.jsonl',
#  'News/earthquake.earthquakeCalifornia2014.jsonl',
#  'News/earthquake.guatemalaEarthquake2012.jsonl',
#  'News/earthquake.italyEarthquakes2012.jsonl',
#  'News/earthquake.nepalEarthquake2015.jsonl',
#  'News/flood.albertaFloods2013.jsonl',
#  'News/flood.floodChoco2019.jsonl',
#  'News/flood.floodColorado2013.jsonl',
#  'News/flood.philipinnesFloods2012.jsonl',
#  'News/flood.queenslandFloods2013.jsonl',
#  'News/flood.southAfricaFloods2019.jsonl',
#  'News/shooting.coloradoStemShooting2019.jsonl',
#  'News/shooting.flSchoolShooting2018.jsonl',
#  'News/shooting.sandiegoSynagogueShooting2019.jsonl',
#  'News/shooting.shootingDallas2017.jsonl',
#  'News/typhoon.cycloneKenneth2019.jsonl',
#  'News/typhoon.joplinTornado2011.jsonl',
#  'News/typhoon.typhoonHagupit2014.jsonl',
#  'News/typhoon.typhoonPablo2012.jsonl',
#  'News/typhoon.typhoonYolanda2013.jsonl',
#  'News/wildfire.australiaBushfire2013.jsonl',
#  'News/wildfire.fireColorado2012.jsonl',
#  'News/wildfire.fireYMM2016.jsonl',
#  'Official/bombing.bostonBombings2013.jsonl',
#  'Official/bombing.westTexasExplosion2013.jsonl',
#  'Official/earthquake.chileEarthquake2014.jsonl',
#  'Official/earthquake.costaRicaEarthquake2012.jsonl',
#  'Official/earthquake.earthquakeBohol2013.jsonl',
#  'Official/earthquake.earthquakeCalifornia2014.jsonl',
#  'Official/earthquake.guatemalaEarthquake2012.jsonl',
#  'Official/earthquake.italyEarthquakes2012.jsonl',
#  'Official/earthquake.nepalEarthquake2015.jsonl',
#  'Official/flood.albertaFloods2013.jsonl',
#  'Official/flood.floodChoco2019.jsonl',
#  'Official/flood.floodColorado2013.jsonl',
#  'Official/flood.philipinnesFloods2012.jsonl',
#  'Official/flood.queenslandFloods2013.jsonl',
#  'Official/flood.southAfricaFloods2019.jsonl',
#  'Official/shooting.coloradoStemShooting2019.jsonl',
#  'Official/shooting.flSchoolShooting2018.jsonl',
#  'Official/shooting.sandiegoSynagogueShooting2019.jsonl',
#  'Official/shooting.shootingDallas2017.jsonl',
#  'Official/typhoon.cycloneKenneth2019.jsonl',
#  'Official/typhoon.joplinTornado2011.jsonl',
#  'Official/typhoon.typhoonHagupit2014.jsonl',
#  'Official/typhoon.typhoonPablo2012.jsonl',
#  'Official/typhoon.typhoonYolanda2013.jsonl',
#  'Official/wildfire.australiaBushfire2013.jsonl',
#  'Official/wildfire.fireColorado2012.jsonl',
#  'Official/wildfire.fireYMM2016.jsonl',
#  'OriginalEvent/bombing.bostonBombings2013.jsonl',
#  'OriginalEvent/bombing.westTexasExplosion2013.jsonl',
#  'OriginalEvent/earthquake.chileEarthquake2014.jsonl',
#  'OriginalEvent/earthquake.costaRicaEarthquake2012.jsonl',
#  'OriginalEvent/earthquake.earthquakeBohol2013.jsonl',
#  'OriginalEvent/earthquake.earthquakeCalifornia2014.jsonl',
#  'OriginalEvent/earthquake.guatemalaEarthquake2012.jsonl',
#  'OriginalEvent/earthquake.italyEarthquakes2012.jsonl',
#  'OriginalEvent/earthquake.nepalEarthquake2015.jsonl',
#  'OriginalEvent/flood.albertaFloods2013.jsonl',
#  'OriginalEvent/flood.floodChoco2019.jsonl',
#  'OriginalEvent/flood.floodColorado2013.jsonl',
#  'OriginalEvent/flood.philipinnesFloods2012.jsonl',
#  'OriginalEvent/flood.queenslandFloods2013.jsonl',
#  'OriginalEvent/flood.southAfricaFloods2019.jsonl',
#  'OriginalEvent/shooting.coloradoStemShooting2019.jsonl',
#  'OriginalEvent/shooting.flSchoolShooting2018.jsonl',
#  'OriginalEvent/shooting.sandiegoSynagogueShooting2019.jsonl',
#  'OriginalEvent/shooting.shootingDallas2017.jsonl',
#  'OriginalEvent/typhoon.cycloneKenneth2019.jsonl',
#  'OriginalEvent/typhoon.joplinTornado2011.jsonl',
#  'OriginalEvent/typhoon.typhoonHagupit2014.jsonl',
#  'OriginalEvent/typhoon.typhoonPablo2012.jsonl',
#  'OriginalEvent/typhoon.typhoonYolanda2013.jsonl',
#  'OriginalEvent/wildfire.australiaBushfire2013.jsonl',
#  'OriginalEvent/wildfire.fireColorado2012.jsonl',
#  'OriginalEvent/wildfire.fireYMM2016.jsonl',
#  'Priority/bombing.bostonBombings2013.jsonl',
#  'Priority/bombing.westTexasExplosion2013.jsonl',
#  'Priority/earthquake.chileEarthquake2014.jsonl',
#  'Priority/earthquake.costaRicaEarthquake2012.jsonl',
#  'Priority/earthquake.earthquakeBohol2013.jsonl',
#  'Priority/earthquake.earthquakeCalifornia2014.jsonl',
#  'Priority/earthquake.guatemalaEarthquake2012.jsonl',
#  'Priority/earthquake.italyEarthquakes2012.jsonl',
#  'Priority/earthquake.nepalEarthquake2015.jsonl',
#  'Priority/flood.albertaFloods2013.jsonl',
#  'Priority/flood.floodChoco2019.jsonl',
#  'Priority/flood.floodColorado2013.jsonl',
#  'Priority/flood.philipinnesFloods2012.jsonl',
#  'Priority/flood.queenslandFloods2013.jsonl',
#  'Priority/flood.southAfricaFloods2019.jsonl',
#  'Priority/shooting.coloradoStemShooting2019.jsonl',
#  'Priority/shooting.flSchoolShooting2018.jsonl',
#  'Priority/shooting.sandiegoSynagogueShooting2019.jsonl',
#  'Priority/shooting.shootingDallas2017.jsonl',
#  'Priority/typhoon.cycloneKenneth2019.jsonl',
#  'Priority/typhoon.joplinTornado2011.jsonl',
#  'Priority/typhoon.typhoonHagupit2014.jsonl',
#  'Priority/typhoon.typhoonPablo2012.jsonl',
#  'Priority/typhoon.typhoonYolanda2013.jsonl',
#  'Priority/wildfire.australiaBushfire2013.jsonl',
#  'Priority/wildfire.fireColorado2012.jsonl',
#  'Priority/wildfire.fireYMM2016.jsonl',
#  'SearchAndRescue/bombing.bostonBombings2013.jsonl',
#  'SearchAndRescue/bombing.westTexasExplosion2013.jsonl',
#  'SearchAndRescue/earthquake.chileEarthquake2014.jsonl',
#  'SearchAndRescue/earthquake.costaRicaEarthquake2012.jsonl',
#  'SearchAndRescue/earthquake.earthquakeBohol2013.jsonl',
#  'SearchAndRescue/earthquake.earthquakeCalifornia2014.jsonl',
#  'SearchAndRescue/earthquake.guatemalaEarthquake2012.jsonl',
#  'SearchAndRescue/earthquake.italyEarthquakes2012.jsonl',
#  'SearchAndRescue/earthquake.nepalEarthquake2015.jsonl',
#  'SearchAndRescue/flood.albertaFloods2013.jsonl',
#  'SearchAndRescue/flood.floodChoco2019.jsonl',
#  'SearchAndRescue/flood.floodColorado2013.jsonl',
#  'SearchAndRescue/flood.philipinnesFloods2012.jsonl',
#  'SearchAndRescue/flood.queenslandFloods2013.jsonl',
#  'SearchAndRescue/flood.southAfricaFloods2019.jsonl',
#  'SearchAndRescue/shooting.coloradoStemShooting2019.jsonl',
#  'SearchAndRescue/shooting.flSchoolShooting2018.jsonl',
#  'SearchAndRescue/shooting.sandiegoSynagogueShooting2019.jsonl',
#  'SearchAndRescue/shooting.shootingDallas2017.jsonl',
#  'SearchAndRescue/typhoon.cycloneKenneth2019.jsonl',
#  'SearchAndRescue/typhoon.joplinTornado2011.jsonl',
#  'SearchAndRescue/typhoon.typhoonHagupit2014.jsonl',
#  'SearchAndRescue/typhoon.typhoonPablo2012.jsonl',
#  'SearchAndRescue/typhoon.typhoonYolanda2013.jsonl',
#  'SearchAndRescue/wildfire.australiaBushfire2013.jsonl',
#  'SearchAndRescue/wildfire.fireColorado2012.jsonl',
#  'SearchAndRescue/wildfire.fireYMM2016.jsonl',
#  'Sentiment/bombing.bostonBombings2013.jsonl',
#  'Sentiment/bombing.westTexasExplosion2013.jsonl',
#  'Sentiment/earthquake.chileEarthquake2014.jsonl',
#  'Sentiment/earthquake.costaRicaEarthquake2012.jsonl',
#  'Sentiment/earthquake.earthquakeBohol2013.jsonl',
#  'Sentiment/earthquake.earthquakeCalifornia2014.jsonl',
#  'Sentiment/earthquake.guatemalaEarthquake2012.jsonl',
#  'Sentiment/earthquake.italyEarthquakes2012.jsonl',
#  'Sentiment/earthquake.nepalEarthquake2015.jsonl',
#  'Sentiment/flood.albertaFloods2013.jsonl',
#  'Sentiment/flood.floodChoco2019.jsonl',
#  'Sentiment/flood.floodColorado2013.jsonl',
#  'Sentiment/flood.philipinnesFloods2012.jsonl',
#  'Sentiment/flood.queenslandFloods2013.jsonl',
#  'Sentiment/flood.southAfricaFloods2019.jsonl',
#  'Sentiment/shooting.coloradoStemShooting2019.jsonl',
#  'Sentiment/shooting.flSchoolShooting2018.jsonl',
#  'Sentiment/shooting.sandiegoSynagogueShooting2019.jsonl',
#  'Sentiment/shooting.shootingDallas2017.jsonl',
#  'Sentiment/typhoon.cycloneKenneth2019.jsonl',
#  'Sentiment/typhoon.joplinTornado2011.jsonl',
#  'Sentiment/typhoon.typhoonHagupit2014.jsonl',
#  'Sentiment/typhoon.typhoonPablo2012.jsonl',
#  'Sentiment/typhoon.typhoonYolanda2013.jsonl',
#  'Sentiment/wildfire.australiaBushfire2013.jsonl',
#  'Sentiment/wildfire.fireColorado2012.jsonl',
#  'Sentiment/wildfire.fireYMM2016.jsonl',
#  'ServiceAvailable/bombing.bostonBombings2013.jsonl',
#  'ServiceAvailable/bombing.westTexasExplosion2013.jsonl',
#  'ServiceAvailable/earthquake.chileEarthquake2014.jsonl',
#  'ServiceAvailable/earthquake.costaRicaEarthquake2012.jsonl',
#  'ServiceAvailable/earthquake.earthquakeBohol2013.jsonl',
#  'ServiceAvailable/earthquake.earthquakeCalifornia2014.jsonl',
#  'ServiceAvailable/earthquake.guatemalaEarthquake2012.jsonl',
#  'ServiceAvailable/earthquake.italyEarthquakes2012.jsonl',
#  'ServiceAvailable/earthquake.nepalEarthquake2015.jsonl',
#  'ServiceAvailable/flood.albertaFloods2013.jsonl',
#  'ServiceAvailable/flood.floodChoco2019.jsonl',
#  'ServiceAvailable/flood.floodColorado2013.jsonl',
#  'ServiceAvailable/flood.philipinnesFloods2012.jsonl',
#  'ServiceAvailable/flood.queenslandFloods2013.jsonl',
#  'ServiceAvailable/flood.southAfricaFloods2019.jsonl',
#  'ServiceAvailable/shooting.coloradoStemShooting2019.jsonl',
#  'ServiceAvailable/shooting.flSchoolShooting2018.jsonl',
#  'ServiceAvailable/shooting.sandiegoSynagogueShooting2019.jsonl',
#  'ServiceAvailable/shooting.shootingDallas2017.jsonl',
#  'ServiceAvailable/typhoon.cycloneKenneth2019.jsonl',
#  'ServiceAvailable/typhoon.joplinTornado2011.jsonl',
#  'ServiceAvailable/typhoon.typhoonHagupit2014.jsonl',
#  'ServiceAvailable/typhoon.typhoonPablo2012.jsonl',
#  'ServiceAvailable/typhoon.typhoonYolanda2013.jsonl',
#  'ServiceAvailable/wildfire.australiaBushfire2013.jsonl',
#  'ServiceAvailable/wildfire.fireColorado2012.jsonl',
#  'ServiceAvailable/wildfire.fireYMM2016.jsonl',
#  'ThirdPartyObservation/bombing.bostonBombings2013.jsonl',
#  'ThirdPartyObservation/bombing.westTexasExplosion2013.jsonl',
#  'ThirdPartyObservation/earthquake.chileEarthquake2014.jsonl',
#  'ThirdPartyObservation/earthquake.costaRicaEarthquake2012.jsonl',
#  'ThirdPartyObservation/earthquake.earthquakeBohol2013.jsonl',
#  'ThirdPartyObservation/earthquake.earthquakeCalifornia2014.jsonl',
#  'ThirdPartyObservation/earthquake.guatemalaEarthquake2012.jsonl',
#  'ThirdPartyObservation/earthquake.italyEarthquakes2012.jsonl',
#  'ThirdPartyObservation/earthquake.nepalEarthquake2015.jsonl',
#  'ThirdPartyObservation/flood.albertaFloods2013.jsonl',
#  'ThirdPartyObservation/flood.floodChoco2019.jsonl',
#  'ThirdPartyObservation/flood.floodColorado2013.jsonl',
#  'ThirdPartyObservation/flood.philipinnesFloods2012.jsonl',
#  'ThirdPartyObservation/flood.queenslandFloods2013.jsonl',
#  'ThirdPartyObservation/flood.southAfricaFloods2019.jsonl',
#  'ThirdPartyObservation/shooting.coloradoStemShooting2019.jsonl',
#  'ThirdPartyObservation/shooting.flSchoolShooting2018.jsonl',
#  'ThirdPartyObservation/shooting.sandiegoSynagogueShooting2019.jsonl',
#  'ThirdPartyObservation/shooting.shootingDallas2017.jsonl',
#  'ThirdPartyObservation/typhoon.cycloneKenneth2019.jsonl',
#  'ThirdPartyObservation/typhoon.joplinTornado2011.jsonl',
#  'ThirdPartyObservation/typhoon.typhoonHagupit2014.jsonl',
#  'ThirdPartyObservation/typhoon.typhoonPablo2012.jsonl',
#  'ThirdPartyObservation/typhoon.typhoonYolanda2013.jsonl',
#  'ThirdPartyObservation/wildfire.australiaBushfire2013.jsonl',
#  'ThirdPartyObservation/wildfire.fireColorado2012.jsonl',
#  'ThirdPartyObservation/wildfire.fireYMM2016.jsonl',
#  'Volunteer/bombing.bostonBombings2013.jsonl',
#  'Volunteer/bombing.westTexasExplosion2013.jsonl',
#  'Volunteer/earthquake.chileEarthquake2014.jsonl',
#  'Volunteer/earthquake.costaRicaEarthquake2012.jsonl',
#  'Volunteer/earthquake.earthquakeBohol2013.jsonl',
#  'Volunteer/earthquake.earthquakeCalifornia2014.jsonl',
#  'Volunteer/earthquake.guatemalaEarthquake2012.jsonl',
#  'Volunteer/earthquake.italyEarthquakes2012.jsonl',
#  'Volunteer/earthquake.nepalEarthquake2015.jsonl',
#  'Volunteer/flood.albertaFloods2013.jsonl',
#  'Volunteer/flood.floodChoco2019.jsonl',
#  'Volunteer/flood.floodColorado2013.jsonl',
#  'Volunteer/flood.philipinnesFloods2012.jsonl',
#  'Volunteer/flood.queenslandFloods2013.jsonl',
#  'Volunteer/flood.southAfricaFloods2019.jsonl',
#  'Volunteer/shooting.coloradoStemShooting2019.jsonl',
#  'Volunteer/shooting.flSchoolShooting2018.jsonl',
#  'Volunteer/shooting.sandiegoSynagogueShooting2019.jsonl',
#  'Volunteer/shooting.shootingDallas2017.jsonl',
#  'Volunteer/typhoon.cycloneKenneth2019.jsonl',
#  'Volunteer/typhoon.joplinTornado2011.jsonl',
#  'Volunteer/typhoon.typhoonHagupit2014.jsonl',
#  'Volunteer/typhoon.typhoonPablo2012.jsonl',
#  'Volunteer/typhoon.typhoonYolanda2013.jsonl',
#  'Volunteer/wildfire.australiaBushfire2013.jsonl',
#  'Volunteer/wildfire.fireColorado2012.jsonl',
#  'Volunteer/wildfire.fireYMM2016.jsonl',
#  'Weather/bombing.bostonBombings2013.jsonl',
#  'Weather/bombing.westTexasExplosion2013.jsonl',
#  'Weather/earthquake.chileEarthquake2014.jsonl',
#  'Weather/earthquake.costaRicaEarthquake2012.jsonl',
#  'Weather/earthquake.earthquakeBohol2013.jsonl',
#  'Weather/earthquake.earthquakeCalifornia2014.jsonl',
#  'Weather/earthquake.guatemalaEarthquake2012.jsonl',
#  'Weather/earthquake.italyEarthquakes2012.jsonl',
#  'Weather/earthquake.nepalEarthquake2015.jsonl',
#  'Weather/flood.albertaFloods2013.jsonl',
#  'Weather/flood.floodChoco2019.jsonl',
#  'Weather/flood.floodColorado2013.jsonl',
#  'Weather/flood.philipinnesFloods2012.jsonl',
#  'Weather/flood.queenslandFloods2013.jsonl',
#  'Weather/flood.southAfricaFloods2019.jsonl',
#  'Weather/shooting.coloradoStemShooting2019.jsonl',
#  'Weather/shooting.flSchoolShooting2018.jsonl',
#  'Weather/shooting.sandiegoSynagogueShooting2019.jsonl',
#  'Weather/shooting.shootingDallas2017.jsonl',
#  'Weather/typhoon.cycloneKenneth2019.jsonl',
#  'Weather/typhoon.joplinTornado2011.jsonl',
#  'Weather/typhoon.typhoonHagupit2014.jsonl',
#  'Weather/typhoon.typhoonPablo2012.jsonl',
#  'Weather/typhoon.typhoonYolanda2013.jsonl',
#  'Weather/wildfire.australiaBushfire2013.jsonl',
#  'Weather/wildfire.fireColorado2012.jsonl',
#  'Weather/wildfire.fireYMM2016.jsonl']

# %%
corpus_reader.categories()
# Out:
# ['Advice',
#  'CleanUp',
#  'ContextualInformation',
#  'Discussion',
#  'Donations',
#  'EmergingThreats',
#  'Factoid',
#  'FirstPartyObservation',
#  'GoodsServices',
#  'Hashtags',
#  'InformationWanted',
#  'Irrelevant',
#  'Location',
#  'MovePeople',
#  'MultimediaShare',
#  'NewSubEvent',
#  'News',
#  'Official',
#  'OriginalEvent',
#  'Priority',
#  'SearchAndRescue',
#  'Sentiment',
#  'ServiceAvailable',
#  'ThirdPartyObservation',
#  'Volunteer',
#  'Weather']

# %%
# corpus_reader.docs(corpus_reader.resolve(categories='Advice'))
